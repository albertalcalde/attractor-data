# %%
from generate_data import generate_traj_data
import numpy as np

case = 'C'
IC = [1.5, 1.5, 0.5]
T = 1000
dt = 0.01

generate_traj_data(case, IC, T, dt)

# %%
import matplotlib.pyplot as plt

# Check that the data was saved properly
y = np.load('caseB.npy')
np.shape(y)

# 3D Plot of the trajectory
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(y[0], y[1], y[2], lw=1, color='b')
ax.set_title('Generated trajectory')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()
